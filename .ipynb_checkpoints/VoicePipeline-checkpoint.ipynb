# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from os                import walk
from pydub             import AudioSegment
from pydub.utils       import get_array_type
from pydub.utils       import mediainfo
from pydub.silence     import split_on_silence
from datasets          import load_dataset
from torchaudio.utils  import download_asset
from scipy             import signal
from scipy.io          import wavfile
from matplotlib.pyplot import figure
from tqdm              import tqdm
from os                import listdir
from os.path           import isfile, join
from datetime          import datetime
from pyctcdecode       import build_ctcdecoder
from pprint            import pprint

import matplotlib.pyplot as plt
import pandas            as pd
import numpy             as np
import soundfile         as sf

import git
import os
import jiwer
import IPython
import array
import librosa
import torch
import torchaudio
# Out:
# kenlm python bindings are not installed. Most likely you want to install it using: pip install https://github.com/kpu/kenlm/archive/master.zip
# kenlm python bindings are not installed. Most likely you want to install it using: pip install https://github.com/kpu/kenlm/archive/master.zip

# %% [markdown]
# <h1 style="background-color:#EBA11F;"> <center> Hebrew: word reading rate: 200-400 per minute </center></h1>

# %% [markdown]
# 1. https://thegrinder.co.il/%D7%9E%D7%93%D7%99%D7%93%D7%AA-%D7%96%D7%9E%D7%A0%D7%99-%D7%A9%D7%94%D7%99%D7%99%D7%94-%D7%96%D7%9E%D7%9F-%D7%A9%D7%94%D7%99%D7%99%D7%94-%D7%98%D7%95%D7%91/#:~:text=%D7%9E%D7%97%D7%A7%D7%A8%D7%99%D7%9D%20%D7%9E%D7%A8%D7%90%D7%99%D7%9D%20%D7%A9%D7%9E%D7%9E%D7%95%D7%A6%D7%A2%20%D7%A7%D7%A6%D7%91%20%D7%A7%D7%A8%D7%99%D7%90%D7%AA,%D7%9E%D7%95%D7%92%D7%91%D7%9C%D7%99%D7%9D%20%D7%91%D7%9E%D7%A1%D7%A4%D7%A8%20%D7%AA%D7%96%D7%95%D7%96%D7%95%D7%AA%20%D7%94%D7%A2%D7%99%D7%A0%D7%99%D7%99%D7%9D%20%D7%94%D7%90%D7%A4%D7%A9%D7%A8%D7%99.

# %% [markdown]
# <p style="color:red;">2. we must calc the number AFTER removing silence</p>

# %% [markdown]
# <h1 style="background-color:LightGreen;"> <center> GPU / CPU </center></h1>

# %%
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
DEVICE
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# <h1 style="background-color:LightGreen;"> <center> Pipeline Utils </center></h1>

# %%
def get_total_speaking_length(speech_timestamps):
    total = 0
    for val in speech_timestamps:
        tmp = val['end'] - val['start']
        total = total + tmp
    return total

# %%
def run_pipeline(vad_model, vad_utils, source_file, dest_file, text, sample_rate):
    
    # 1. get silero util functions
    (get_speech_timestamps, save_audio, read_audio,VADIterator, collect_chunks) = vad_utils
    
    # 2. get file VAD
    wav_audio         = read_audio(source_file, sampling_rate=sample_rate)       
    full_audio_lenth  = len(wav_audio) / sample_rate
    speech_timestamps = get_speech_timestamps(wav_audio, vad_model, sampling_rate=sample_rate)
    
    # 3. calc staicics
    new_file_length   = get_total_speaking_length(speech_timestamps) / sample_rate
    text_length       = len(text.split())
#     if text_length < (200/60*new_file_length*0.7):
#         print(f"Outlier: {source_file}, Text length: {text_length}, File Length: {full_audio_lenth} seconds")
#         return None, None
    
    # 4. convert to new file (without noise)    
    save_audio("tmp.wav",collect_chunks(speech_timestamps, wav_audio), sampling_rate=sample_rate)
    
    # 5. convert to mp3
    AudioSegment.from_wav("tmp.wav").export(dest_file, format="mp3")
    os.remove("tmp.wav")

    
    return text_length, new_file_length

# %%
def run_on_new_police_data(vad_model, vad_utils, source_folder, dest_folder, sample_rate, gt_excell_path):
    
    # get poilce GT text
    df_gt                  = pd.read_excel(gt_excell_path)
    
    
    # get sub folder list
    folder_list   = [f for f in listdir(source_folder) if not isfile(join(source_folder, f))]        
    df_statistics = pd.DataFrame()

    files_name        = []    
    gt_len            = []
    file_length       = []      
    gt_text           = []
    
    for folder_name in tqdm(folder_list):
        
        # --- get wav file
        splitted_wav_folder = f"{source_folder}/{folder_name}"
        splitted_files      = [entry for entry in os.listdir(splitted_wav_folder) if os.path.isfile(os.path.join(splitted_wav_folder, entry))]
        
        # --- get GT text
        gt_list             = df_gt[df_gt['file'] == f"{folder_name}.mp3"]['text'].values                
                        
        for i in range(len(splitted_files)): 
            part           = "%04d" % (i,)
            full_src       = f"{source_folder}/{folder_name}/{folder_name}_{part}.wav"       
            full_dst       = f"{dest_folder}/{folder_name}_{part}.mp3"       
            
            
            text_length, new_file_length = run_pipeline(vad_model, 
                                                        vad_utils, 
                                                        full_src, 
                                                        full_dst, 
                                                        gt_list[i], 
                                                        sample_rate)
            # if outlier
            if text_length is None:
                continue
            
            gt_text.append(gt_list[i])
            files_name.append(f"{folder_name}_{part}")
            gt_len.append(text_length)
            file_length.append(new_file_length)        
                        

    df_statistics = pd.DataFrame(data = {"File":   files_name,
                                  "Duration":      file_length,
                                  "Text Length":   gt_len,
                                  "Text":          gt_text
                                  })
    
    df_statistics.to_csv(f"{dest_folder}/statistics.csv")

# %% [markdown]
# <h1 style="background-color:LightGreen;"> <center> Amit Example </center></h1>

# %%
vad_model, vad_utils = torch.hub.load(repo_or_dir  = 'snakers4/silero-vad',
                                      model        = 'silero_vad',
                                      force_reload = True,
                                      onnx         = False)
# Out:
# Downloading: "https://github.com/snakers4/silero-vad/zipball/master" to /home/amitli/.cache/torch/hub/master.zip

# %%
gt_excell_path = "/home/amitli/Datasets/Unit_Tests/new_corpus.xlsx"
source_folder  = "/home/amitli/Datasets/Unit_Tests/Source"
dest_folder    = "/home/amitli/Datasets/Unit_Tests/Dest"
sample_rate    = 8000 

run_on_new_police_data(vad_model, vad_utils, source_folder, dest_folder, sample_rate, gt_excell_path)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:31<00:00, 15.61s/it]

# %%
df = pd.read_csv("/home/amitli/Datasets/Unit_Tests/Dest/statistics.csv")
df.head()

# %%
# not good:
#IPython.display.Audio("/home/amitli/Datasets/Unit_Tests/Dest/-37_ZAraHQM_0011.wav")

# %%
IPython.display.Audio("/home/amitli/Datasets/Unit_Tests/Dest/_30FJ_jSekk_0165.wav")

# %%
IPython.display.Audio("/home/amitli/Datasets/Unit_Tests/Dest/_30FJ_jSekk_0165.mp3")

# %%
IPython.display.Audio("/home/amitli/Datasets/Unit_Tests/Source/_30FJ_jSekk/_30FJ_jSekk_0008.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
